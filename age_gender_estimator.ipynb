# %% [markdown]
# # Age Estimation and Gender Classification
#
# In this assignment, you will train CNN models to estimate a person's age and predict their gender based on face images. Please read carefully all the instructions before you start to write your code.
#
# **Your Tasks**
#
# You are supposed to train two CNN models.
# - Model A: Train a CNN model from scratch, following a few restrictions. Save this model as `age_gender_A.keras`
# - Model B: Fine-tune a pre-trained model to perform the same task. Save this model as `age_gender_B.keras`
#
# **Dataset**
#
# Your models will be trained and validated on a folder `train_val/` containing 5,000 labeled face images (size: 128 x 128), originated from the UTKFace dataset. During the assessment phase, your code will be tested on unseen test data.
#
# **Performance Metric**
#
# The evaluation of your models on the test set will be based on the following metrics:
# - age estimation: - Mean Absolute Error (MAE)
# - gender prediction: accuracy
#
# **GPU Time Management**
#
# Please use the available GPU time wisely, as there are some limitations on free GPU usage. It is said the users can use up to 12 hours in row in Google Colab. But many people found they reached its limit far less than 12 hours. To minimize the risk of reaching the limit, consider the following suggestions:
# 1. Ensure you have a stable internet connection.
# 2. Carefully validate your hyperparameters before starting the training process.
# 3. Based on past experience, each model should be trained in less than 2 hours. If the training time is significantly longer, you may need to adjust your model architecture.

# %% [markdown]
# ## Setting Up: Mount the google drive
# Mount your google drive to the notebook. Also don't forget to **enable GPU** before your training.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Visualize a few photos
# It's always beneficial to thoroughly understand your data before beginning the training process. To get a first-hand impression of the dataset, please display a minimum of 20 images from the `train_val/` folder, along with their corresponding age and gender labels. This will help you gain initial insights into the dataset.

# %%
import os
import cv2
import random
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, Sequential

# %%
folder_train_val = '/content/drive/MyDrive/train_val/'

all_image_files = [file for file in os.listdir(folder_train_val) if file.lower().endswith('.jpg')]

random.seed(0)
selected_files = random.sample(all_image_files, 20)

def visualize_images(dataset_path, filenames):
    plt.figure(figsize=(15, 10))
    for i, filename in enumerate(filenames):
        img_path = os.path.join(dataset_path, filename)
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        labels = filename.split('_')
        age = int(labels[0])
        gender = 'Male' if int(labels[1]) == 0 else 'Female'

        plt.subplot(4, 5, i + 1)
        plt.imshow(img)
        plt.title(f'Age: {age}\nGender: {gender}')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

visualize_images(folder_train_val, selected_files)

# %% [markdown]
# ## Step 1: Data Pre-Processing
# In this step, you will perform necessary pre-processing tasks before feeding the data into a CNN. The pre-processing includes:
#
# 1. Splitting the data into training and validation sets.
# 2. Loading image data, gender labels and age values, and rescaling pixel values (originally integers between 0 and 255) to the range [0, 1].
# 3. Data augmentation
#
# The first two pre-processing steps have already been completed for you. Your task in this step is limited to:
#
# 3. Data augmentation
#
# Please note:
#
# - Do not modify any part of the provided code except the section marked with ########.
# - Do not rescale the age values to the range [0,1], as the original values are used during the testing stage. Rescaling them would significantly impact testing performance.

# %%
folder_train_val = '/content/drive/MyDrive/train_val/'
all_image_files = [file for file in os.listdir(folder_train_val) if file.lower().endswith(('.jpg'))]

# Shuffle the dataset to ensure random distribution
random.seed(0)  # Ensure reproducibility
random.shuffle(all_image_files)

# Calculate the number of images for each set
n_train_val = len(all_image_files)
train_end = int(n_train_val * 0.8)

# Split the dataset
train_image_files = all_image_files[:train_end]
val_image_files = all_image_files[train_end:]
print(f"Number of images for training: {len(train_image_files)}")
print(f"Number of images for validation: {len(val_image_files)}")

def load_imgs_lables(dataset_path,filenames):
  print('load all image data, age and gender labels...')
  images = []
  age_labels = []
  gender_labels = []
  for current_file_name in filenames:
    img = cv2.imread(os.path.join(dataset_path, current_file_name))
    img = img / 255.0  # Normalize pixel values
    labels = current_file_name.split('_')
    age_label = int(labels[0])
    gender_label = int(labels[1])
    age_labels.append(age_label)
    gender_labels.append(gender_label)
    images.append(img)

  # Convert to NumPy arrays
  images = np.array(images)
  age_labels = np.array(age_labels)
  gender_labels = np.array(gender_labels)
  return images, age_labels, gender_labels

# load data from the training set
train_images, train_age, train_gender = load_imgs_lables(folder_train_val,train_image_files)

# load data from the validation set
val_images, val_age, val_gender = load_imgs_lables(folder_train_val,val_image_files)

#
### augmentation def ###
#
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
    layers.RandomTranslation(0.2, 0.2),
    layers.RandomShear(0.1)
])
# Out:
# Number of images for training: 4000
# Number of images for validation: 1000
# load all image data, age and gender labels...
# load all image data, age and gender labels...

# %% [markdown]
# ## STEP2A: Build your own CNN network
# In this step, you will define your own CNN model for identifying gender and predicting age. Although there are two tasks, you only need to build one CNN model with two outputs. You may refer to online resources for solutions.
#
# Here are the key requirements and restrictions for your network:
# 1.	The input size must be 128 x 128 x 3, which means you **should not resize** the original images. This is because my test code relies on this particular input size. Any other size will cause problem in the testing stage.
# 2.  Please treat the gender classification as a binary problem, i.e., **the output layer for the gender branch has only 1 unit**, instead of 2. Although it is technically correct to treat gender classification as a multi-class problem with 2 classes, i.e., 2 units in the last layer, the test code only supports a 1-unit last-layer configuration for the gender branch.
# 3.	The size of feature maps being fed to the first fully connected layer must be less than 10 x 10, while there is no number limitation about the depth.
# 4.	Incorporate techniques to prevent overfitting as appropriate.
#
# At the end of your implementation, use `modelA.summary()` to display the model architecture and use `plot_model()` to visualize the architecture.

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import plot_model

input_layer = Input(shape=(128, 128, 3))

x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_layer)
x = BatchNormalization()(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2))(x)
x = Dropout(0.2)(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2))(x)
x = Dropout(0.2)(x)

x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2))(x)
x = Dropout(0.3)(x)

x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2))(x)  # Reduces from 16x16 to 8x8
x = Dropout(0.5)(x)

x = Flatten()(x)

x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)  # Keep the existing dropout layer

gender_output = Dense(1, activation='sigmoid', name='gender_output')(x)  # Binary gender classification
age_output = Dense(1, activation='relu', name='age_output')(x)          # Age regression

modelA = Model(inputs=input_layer, outputs=[gender_output, age_output])

modelA.summary()

plot_model(modelA, show_shapes=True, dpi=100)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 128, 128, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 128, 128, 32)   │            896 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 128, 128, 32)   │            128 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 128, 128, 32)   │          9,248 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 64, 64, 32)     │              0 │ conv2d_1[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 64, 64, 32)     │              0 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 64, 64, 64)     │         18,496 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 64, 64, 64)     │            256 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 64, 64, 64)     │         36,928 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 32, 32, 64)     │              0 │ conv2d_3[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 32, 32, 64)     │              0 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 32, 32, 128)    │         73,856 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 32, 32, 128)    │            512 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 32, 32, 128)    │        147,584 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 16, 16, 128)    │              0 │ conv2d_5[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 16, 16, 128)    │              0 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 16, 16, 256)    │        295,168 │ dropout_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 16, 16, 256)    │          1,024 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 16, 16, 256)    │        590,080 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 8, 8, 256)      │              0 │ conv2d_7[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 8, 8, 256)      │              0 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten (Flatten)         │ (None, 16384)          │              0 │ dropout_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 512)            │      8,389,120 │ flatten[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_4 (Dropout)       │ (None, 512)            │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gender_output (Dense)     │ (None, 1)              │            513 │ dropout_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ age_output (Dense)        │ (None, 1)              │            513 │ dropout_4[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 9,564,322 (36.48 MB)
#  Trainable params: 9,563,362 (36.48 MB)
#  Non-trainable params: 960 (3.75 KB)

# %% [markdown]
# ## STEP3A: Compile and train your model
# Compile and train your model here.
# Save your model by `modelA.save(your_model_folder+"age_gender_A.keras")` after training.
#
# **DON'T use any other name for your model file.** This is because my test code relies on this particular model name. Any other file name will cause problem in the testing stage.
#
# **Save the model with `save()`** to save the entire model (including a model's architecture, weights, and training configuration) as a `.keras` zip archive. Don't save it with `save_weights()`.

# %%
import os
import numpy as np
import tensorflow as tf

# %%
from re import VERBOSE
from tensorflow.keras.callbacks import ReduceLROnPlateau

train_dataset = tf.data.Dataset.from_tensor_slices((train_images, {'gender_output': train_gender, 'age_output': train_age}))
train_dataset = train_dataset.batch(128).prefetch(tf.data.AUTOTUNE)
val_dataset = tf.data.Dataset.from_tensor_slices((val_images, {'gender_output': val_gender, 'age_output': val_age}))
val_dataset = val_dataset.batch(128).prefetch(tf.data.AUTOTUNE)

from tensorflow.keras.callbacks import EarlyStopping

import os


modelA.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss={'gender_output': 'binary_crossentropy', 'age_output': 'mean_absolute_error'},
    metrics={'gender_output': ['accuracy'], 'age_output': ['mae']}
)

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=15,
    min_delta = 0.01,
    restore_best_weights=True
)

LRP = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, VERBOSE=1)


epochs = 110
historyA = modelA.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=epochs,
    callbacks=[early_stopping, LRP]
    #callbacks=[LRP]


)

folder_models = '/content/drive/MyDrive/'
if not os.path.exists(folder_models):
    os.makedirs(folder_models)

modelA.save(os.path.join(folder_models, 'age_gender_A.keras'))

print("Model training and saving completed.")
# Out:
# Epoch 1/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 367ms/step - age_output_loss: 18.6615 - age_output_mae: 18.6696 - gender_output_accuracy: 0.5189 - gender_output_loss: 1.3774 - loss: 20.0478 - val_age_output_loss: 28.3892 - val_age_output_mae: 28.4089 - val_gender_output_accuracy: 0.4570 - val_gender_output_loss: 0.7028 - val_loss: 29.1116 - learning_rate: 1.0000e-04
# Epoch 2/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - age_output_loss: 14.3333 - age_output_mae: 14.3378 - gender_output_accuracy: 0.5796 - gender_output_loss: 0.9726 - loss: 15.3105 - val_age_output_loss: 24.3812 - val_age_output_mae: 24.3977 - val_gender_output_accuracy: 0.4570 - val_gender_output_loss: 0.7049 - val_loss: 25.1026 - learning_rate: 1.0000e-04
# Epoch 3/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - age_output_loss: 13.7525 - age_output_mae: 13.7559 - gender_output_accuracy: 0.6128 - gender_output_loss: 0.9000 - loss: 14.6561 - val_age_output_loss: 21.0991 - val_age_output_mae: 21.1094 - val_gender_output_accuracy: 0.4570 - val_gender_output_loss: 0.7065 - val_loss: 21.8159 - learning_rate: 1.0000e-04
# Epoch 4/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - age_output_loss: 13.1151 - age_output_mae: 13.1197 - gender_output_accuracy: 0.6531 - gender_output_loss: 0.8358 - loss: 13.9551 - val_age_output_loss: 19.3630 - val_age_output_mae: 19.3671 - val_gender_output_accuracy: 0.5430 - val_gender_output_loss: 0.6836 - val_loss: 20.0507 - learning_rate: 1.0000e-04
# Epoch 5/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - age_output_loss: 12.5427 - age_output_mae: 12.5448 - gender_output_accuracy: 0.6826 - gender_output_loss: 0.7628 - loss: 13.3075 - val_age_output_loss: 18.7800 - val_age_output_mae: 18.7824 - val_gender_output_accuracy: 0.6340 - val_gender_output_loss: 0.6832 - val_loss: 19.4655 - learning_rate: 1.0000e-04
# Epoch 6/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - age_output_loss: 12.0230 - age_output_mae: 12.0263 - gender_output_accuracy: 0.6919 - gender_output_loss: 0.7017 - loss: 12.7281 - val_age_output_loss: 16.7026 - val_age_output_mae: 16.6971 - val_gender_output_accuracy: 0.5430 - val_gender_output_loss: 0.6824 - val_loss: 17.3793 - learning_rate: 1.0000e-04
# Epoch 7/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - age_output_loss: 11.4599 - age_output_mae: 11.4626 - gender_output_accuracy: 0.7095 - gender_output_loss: 0.6934 - loss: 12.1558 - val_age_output_loss: 15.3329 - val_age_output_mae: 15.3242 - val_gender_output_accuracy: 0.4800 - val_gender_output_loss: 0.6827 - val_loss: 16.0067 - learning_rate: 1.0000e-04
# Epoch 8/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 11.0122 - age_output_mae: 11.0132 - gender_output_accuracy: 0.7054 - gender_output_loss: 0.6811 - loss: 11.6943 - val_age_output_loss: 15.4847 - val_age_output_mae: 15.4761 - val_gender_output_accuracy: 0.5020 - val_gender_output_loss: 0.6754 - val_loss: 16.1515 - learning_rate: 1.0000e-04
# Epoch 9/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - age_output_loss: 10.7545 - age_output_mae: 10.7550 - gender_output_accuracy: 0.7298 - gender_output_loss: 0.6192 - loss: 11.3741 - val_age_output_loss: 14.9939 - val_age_output_mae: 14.9836 - val_gender_output_accuracy: 0.5610 - val_gender_output_loss: 0.6634 - val_loss: 15.6468 - learning_rate: 1.0000e-04
# Epoch 10/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 10.3978 - age_output_mae: 10.3995 - gender_output_accuracy: 0.7233 - gender_output_loss: 0.6564 - loss: 11.0559 - val_age_output_loss: 14.9697 - val_age_output_mae: 14.9592 - val_gender_output_accuracy: 0.6680 - val_gender_output_loss: 0.6139 - val_loss: 15.5731 - learning_rate: 1.0000e-04
# Epoch 11/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 9.9240 - age_output_mae: 9.9254 - gender_output_accuracy: 0.7412 - gender_output_loss: 0.6188 - loss: 10.5442 - val_age_output_loss: 14.7064 - val_age_output_mae: 14.6962 - val_gender_output_accuracy: 0.5740 - val_gender_output_loss: 0.6413 - val_loss: 15.3375 - learning_rate: 1.0000e-04
# Epoch 12/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - age_output_loss: 9.7204 - age_output_mae: 9.7237 - gender_output_accuracy: 0.7382 - gender_output_loss: 0.6200 - loss: 10.3436 - val_age_output_loss: 15.0064 - val_age_output_mae: 14.9966 - val_gender_output_accuracy: 0.6210 - val_gender_output_loss: 0.6073 - val_loss: 15.6039 - learning_rate: 1.0000e-04
# Epoch 13/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 9.4998 - age_output_mae: 9.5020 - gender_output_accuracy: 0.7364 - gender_output_loss: 0.6011 - loss: 10.1031 - val_age_output_loss: 14.0124 - val_age_output_mae: 14.0037 - val_gender_output_accuracy: 0.7400 - val_gender_output_loss: 0.5457 - val_loss: 14.5488 - learning_rate: 1.0000e-04
# Epoch 14/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 9.4174 - age_output_mae: 9.4185 - gender_output_accuracy: 0.7553 - gender_output_loss: 0.5849 - loss: 10.0037 - val_age_output_loss: 13.2094 - val_age_output_mae: 13.2013 - val_gender_output_accuracy: 0.7630 - val_gender_output_loss: 0.5146 - val_loss: 13.7153 - learning_rate: 1.0000e-04
# Epoch 15/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 9.2581 - age_output_mae: 9.2611 - gender_output_accuracy: 0.7588 - gender_output_loss: 0.5760 - loss: 9.8372 - val_age_output_loss: 12.4773 - val_age_output_mae: 12.4671 - val_gender_output_accuracy: 0.7780 - val_gender_output_loss: 0.4919 - val_loss: 12.9582 - learning_rate: 1.0000e-04
# Epoch 16/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 9.2398 - age_output_mae: 9.2436 - gender_output_accuracy: 0.7564 - gender_output_loss: 0.5524 - loss: 9.7959 - val_age_output_loss: 11.5205 - val_age_output_mae: 11.5175 - val_gender_output_accuracy: 0.7690 - val_gender_output_loss: 0.4803 - val_loss: 11.9970 - learning_rate: 1.0000e-04
# Epoch 17/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 8.8631 - age_output_mae: 8.8667 - gender_output_accuracy: 0.7579 - gender_output_loss: 0.5770 - loss: 9.4439 - val_age_output_loss: 10.8720 - val_age_output_mae: 10.8729 - val_gender_output_accuracy: 0.7980 - val_gender_output_loss: 0.4546 - val_loss: 11.3259 - learning_rate: 1.0000e-04
# Epoch 18/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 9.0032 - age_output_mae: 9.0054 - gender_output_accuracy: 0.7676 - gender_output_loss: 0.5446 - loss: 9.5499 - val_age_output_loss: 9.6735 - val_age_output_mae: 9.6716 - val_gender_output_accuracy: 0.8010 - val_gender_output_loss: 0.4344 - val_loss: 10.1047 - learning_rate: 1.0000e-04
# Epoch 19/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - age_output_loss: 8.7419 - age_output_mae: 8.7460 - gender_output_accuracy: 0.7826 - gender_output_loss: 0.5031 - loss: 9.2493 - val_age_output_loss: 9.7921 - val_age_output_mae: 9.8108 - val_gender_output_accuracy: 0.8110 - val_gender_output_loss: 0.3937 - val_loss: 10.2025 - learning_rate: 1.0000e-04
# Epoch 20/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - age_output_loss: 8.5891 - age_output_mae: 8.5918 - gender_output_accuracy: 0.7973 - gender_output_loss: 0.4754 - loss: 9.0673 - val_age_output_loss: 9.0579 - val_age_output_mae: 9.0769 - val_gender_output_accuracy: 0.8280 - val_gender_output_loss: 0.3846 - val_loss: 9.4598 - learning_rate: 1.0000e-04
# Epoch 21/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - age_output_loss: 8.3199 - age_output_mae: 8.3231 - gender_output_accuracy: 0.7982 - gender_output_loss: 0.5083 - loss: 8.8312 - val_age_output_loss: 9.5082 - val_age_output_mae: 9.5304 - val_gender_output_accuracy: 0.8250 - val_gender_output_loss: 0.3726 - val_loss: 9.9009 - learning_rate: 1.0000e-04
# Epoch 22/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - age_output_loss: 8.2741 - age_output_mae: 8.2733 - gender_output_accuracy: 0.7985 - gender_output_loss: 0.5059 - loss: 8.7791 - val_age_output_loss: 8.7512 - val_age_output_mae: 8.7512 - val_gender_output_accuracy: 0.8280 - val_gender_output_loss: 0.3997 - val_loss: 9.1501 - learning_rate: 1.0000e-04
# Epoch 23/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 8.2206 - age_output_mae: 8.2231 - gender_output_accuracy: 0.8051 - gender_output_loss: 0.4898 - loss: 8.7132 - val_age_output_loss: 8.8412 - val_age_output_mae: 8.8552 - val_gender_output_accuracy: 0.8410 - val_gender_output_loss: 0.3669 - val_loss: 9.2201 - learning_rate: 1.0000e-04
# Epoch 24/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - age_output_loss: 8.0013 - age_output_mae: 8.0035 - gender_output_accuracy: 0.7972 - gender_output_loss: 0.4849 - loss: 8.4886 - val_age_output_loss: 8.7451 - val_age_output_mae: 8.7556 - val_gender_output_accuracy: 0.8330 - val_gender_output_loss: 0.3613 - val_loss: 9.1150 - learning_rate: 1.0000e-04
# Epoch 25/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 7.9550 - age_output_mae: 7.9590 - gender_output_accuracy: 0.7976 - gender_output_loss: 0.5016 - loss: 8.4604 - val_age_output_loss: 8.6885 - val_age_output_mae: 8.6866 - val_gender_output_accuracy: 0.8460 - val_gender_output_loss: 0.3520 - val_loss: 9.0372 - learning_rate: 1.0000e-04
# Epoch 26/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - age_output_loss: 8.1971 - age_output_mae: 8.2003 - gender_output_accuracy: 0.8063 - gender_output_loss: 0.4793 - loss: 8.6793 - val_age_output_loss: 8.5881 - val_age_output_mae: 8.5899 - val_gender_output_accuracy: 0.8300 - val_gender_output_loss: 0.3763 - val_loss: 8.9646 - learning_rate: 1.0000e-04
# Epoch 27/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 8.0101 - age_output_mae: 8.0143 - gender_output_accuracy: 0.8067 - gender_output_loss: 0.4485 - loss: 8.4628 - val_age_output_loss: 8.4208 - val_age_output_mae: 8.4265 - val_gender_output_accuracy: 0.8320 - val_gender_output_loss: 0.3754 - val_loss: 8.8002 - learning_rate: 1.0000e-04
# Epoch 28/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 7.8837 - age_output_mae: 7.8868 - gender_output_accuracy: 0.8167 - gender_output_loss: 0.4460 - loss: 8.3323 - val_age_output_loss: 8.4692 - val_age_output_mae: 8.4751 - val_gender_output_accuracy: 0.8380 - val_gender_output_loss: 0.3530 - val_loss: 8.8265 - learning_rate: 1.0000e-04
# Epoch 29/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - age_output_loss: 8.0070 - age_output_mae: 8.0113 - gender_output_accuracy: 0.8135 - gender_output_loss: 0.4485 - loss: 8.4598 - val_age_output_loss: 8.1324 - val_age_output_mae: 8.1412 - val_gender_output_accuracy: 0.8350 - val_gender_output_loss: 0.3585 - val_loss: 8.4985 - learning_rate: 1.0000e-04
# Epoch 30/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - age_output_loss: 7.9664 - age_output_mae: 7.9684 - gender_output_accuracy: 0.8203 - gender_output_loss: 0.4328 - loss: 8.4011 - val_age_output_loss: 8.2321 - val_age_output_mae: 8.2562 - val_gender_output_accuracy: 0.8300 - val_gender_output_loss: 0.3821 - val_loss: 8.6371 - learning_rate: 1.0000e-04
# Epoch 31/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 7.7644 - age_output_mae: 7.7653 - gender_output_accuracy: 0.8257 - gender_output_loss: 0.4306 - loss: 8.1958 - val_age_output_loss: 9.5327 - val_age_output_mae: 9.5540 - val_gender_output_accuracy: 0.8380 - val_gender_output_loss: 0.3658 - val_loss: 9.9178 - learning_rate: 1.0000e-04
# Epoch 32/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 7.6931 - age_output_mae: 7.6942 - gender_output_accuracy: 0.8274 - gender_output_loss: 0.4251 - loss: 8.1194 - val_age_output_loss: 8.1610 - val_age_output_mae: 8.1796 - val_gender_output_accuracy: 0.8480 - val_gender_output_loss: 0.3422 - val_loss: 8.5201 - learning_rate: 1.0000e-04
# Epoch 33/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 7.6285 - age_output_mae: 7.6316 - gender_output_accuracy: 0.8338 - gender_output_loss: 0.4070 - loss: 8.0387 - val_age_output_loss: 9.3195 - val_age_output_mae: 9.3304 - val_gender_output_accuracy: 0.8290 - val_gender_output_loss: 0.3613 - val_loss: 9.6901 - learning_rate: 1.0000e-04
# Epoch 34/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 7.8757 - age_output_mae: 7.8793 - gender_output_accuracy: 0.8205 - gender_output_loss: 0.3934 - loss: 8.2728 - val_age_output_loss: 9.1715 - val_age_output_mae: 9.1856 - val_gender_output_accuracy: 0.8440 - val_gender_output_loss: 0.3379 - val_loss: 9.5220 - learning_rate: 1.0000e-04
# Epoch 35/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 7.4320 - age_output_mae: 7.4348 - gender_output_accuracy: 0.8431 - gender_output_loss: 0.3920 - loss: 7.8268 - val_age_output_loss: 7.9067 - val_age_output_mae: 7.9024 - val_gender_output_accuracy: 0.8500 - val_gender_output_loss: 0.3273 - val_loss: 8.2282 - learning_rate: 5.0000e-05
# Epoch 36/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - age_output_loss: 7.2490 - age_output_mae: 7.2533 - gender_output_accuracy: 0.8436 - gender_output_loss: 0.3748 - loss: 7.6282 - val_age_output_loss: 9.5855 - val_age_output_mae: 9.6039 - val_gender_output_accuracy: 0.8490 - val_gender_output_loss: 0.3377 - val_loss: 9.9398 - learning_rate: 5.0000e-05
# Epoch 37/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 7.4185 - age_output_mae: 7.4209 - gender_output_accuracy: 0.8474 - gender_output_loss: 0.3741 - loss: 7.7951 - val_age_output_loss: 7.9755 - val_age_output_mae: 7.9792 - val_gender_output_accuracy: 0.8480 - val_gender_output_loss: 0.3319 - val_loss: 8.3099 - learning_rate: 5.0000e-05
# Epoch 38/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 7.2693 - age_output_mae: 7.2711 - gender_output_accuracy: 0.8469 - gender_output_loss: 0.3849 - loss: 7.6563 - val_age_output_loss: 7.7964 - val_age_output_mae: 7.7953 - val_gender_output_accuracy: 0.8570 - val_gender_output_loss: 0.3240 - val_loss: 8.1176 - learning_rate: 5.0000e-05
# Epoch 39/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 7.1080 - age_output_mae: 7.1127 - gender_output_accuracy: 0.8421 - gender_output_loss: 0.3825 - loss: 7.4952 - val_age_output_loss: 8.4056 - val_age_output_mae: 8.4146 - val_gender_output_accuracy: 0.8460 - val_gender_output_loss: 0.3303 - val_loss: 8.7437 - learning_rate: 5.0000e-05
# Epoch 40/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - age_output_loss: 7.1624 - age_output_mae: 7.1658 - gender_output_accuracy: 0.8499 - gender_output_loss: 0.3605 - loss: 7.5259 - val_age_output_loss: 8.2619 - val_age_output_mae: 8.2713 - val_gender_output_accuracy: 0.8460 - val_gender_output_loss: 0.3462 - val_loss: 8.6157 - learning_rate: 5.0000e-05
# Epoch 41/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - age_output_loss: 7.2224 - age_output_mae: 7.2268 - gender_output_accuracy: 0.8403 - gender_output_loss: 0.3642 - loss: 7.5911 - val_age_output_loss: 8.3947 - val_age_output_mae: 8.4003 - val_gender_output_accuracy: 0.8440 - val_gender_output_loss: 0.3398 - val_loss: 8.7388 - learning_rate: 5.0000e-05
# Epoch 42/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - age_output_loss: 7.0168 - age_output_mae: 7.0200 - gender_output_accuracy: 0.8329 - gender_output_loss: 0.3609 - loss: 7.3807 - val_age_output_loss: 7.9175 - val_age_output_mae: 7.9254 - val_gender_output_accuracy: 0.8530 - val_gender_output_loss: 0.3488 - val_loss: 8.2728 - learning_rate: 5.0000e-05
# Epoch 43/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 7.1462 - age_output_mae: 7.1486 - gender_output_accuracy: 0.8504 - gender_output_loss: 0.3618 - loss: 7.5104 - val_age_output_loss: 7.8189 - val_age_output_mae: 7.8155 - val_gender_output_accuracy: 0.8550 - val_gender_output_loss: 0.3345 - val_loss: 8.1485 - learning_rate: 5.0000e-05
# Epoch 44/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - age_output_loss: 6.9851 - age_output_mae: 6.9885 - gender_output_accuracy: 0.8357 - gender_output_loss: 0.3827 - loss: 7.3711 - val_age_output_loss: 7.7893 - val_age_output_mae: 7.7899 - val_gender_output_accuracy: 0.8550 - val_gender_output_loss: 0.3328 - val_loss: 8.1215 - learning_rate: 2.5000e-05
# Epoch 45/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 6.9929 - age_output_mae: 6.9962 - gender_output_accuracy: 0.8492 - gender_output_loss: 0.3526 - loss: 7.3488 - val_age_output_loss: 7.7016 - val_age_output_mae: 7.6999 - val_gender_output_accuracy: 0.8580 - val_gender_output_loss: 0.3299 - val_loss: 8.0285 - learning_rate: 2.5000e-05
# Epoch 46/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - age_output_loss: 6.9518 - age_output_mae: 6.9548 - gender_output_accuracy: 0.8496 - gender_output_loss: 0.3665 - loss: 7.3213 - val_age_output_loss: 7.7423 - val_age_output_mae: 7.7412 - val_gender_output_accuracy: 0.8570 - val_gender_output_loss: 0.3348 - val_loss: 8.0747 - learning_rate: 2.5000e-05
# Epoch 47/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 6.8905 - age_output_mae: 6.8952 - gender_output_accuracy: 0.8427 - gender_output_loss: 0.3703 - loss: 7.2657 - val_age_output_loss: 7.6721 - val_age_output_mae: 7.6696 - val_gender_output_accuracy: 0.8550 - val_gender_output_loss: 0.3279 - val_loss: 7.9961 - learning_rate: 2.5000e-05
# Epoch 48/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 6.8365 - age_output_mae: 6.8403 - gender_output_accuracy: 0.8366 - gender_output_loss: 0.3808 - loss: 7.2211 - val_age_output_loss: 7.8578 - val_age_output_mae: 7.8549 - val_gender_output_accuracy: 0.8540 - val_gender_output_loss: 0.3272 - val_loss: 8.1807 - learning_rate: 2.5000e-05
# Epoch 49/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 6.9049 - age_output_mae: 6.9081 - gender_output_accuracy: 0.8461 - gender_output_loss: 0.3617 - loss: 7.2699 - val_age_output_loss: 7.7009 - val_age_output_mae: 7.6999 - val_gender_output_accuracy: 0.8560 - val_gender_output_loss: 0.3249 - val_loss: 8.0233 - learning_rate: 2.5000e-05
# Epoch 50/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 6.9358 - age_output_mae: 6.9382 - gender_output_accuracy: 0.8494 - gender_output_loss: 0.3557 - loss: 7.2938 - val_age_output_loss: 7.6905 - val_age_output_mae: 7.6885 - val_gender_output_accuracy: 0.8560 - val_gender_output_loss: 0.3276 - val_loss: 8.0147 - learning_rate: 2.5000e-05
# Epoch 51/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - age_output_loss: 6.7379 - age_output_mae: 6.7409 - gender_output_accuracy: 0.8586 - gender_output_loss: 0.3377 - loss: 7.0788 - val_age_output_loss: 7.6513 - val_age_output_mae: 7.6516 - val_gender_output_accuracy: 0.8600 - val_gender_output_loss: 0.3237 - val_loss: 7.9736 - learning_rate: 2.5000e-05
# Epoch 52/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 6.6823 - age_output_mae: 6.6863 - gender_output_accuracy: 0.8546 - gender_output_loss: 0.3593 - loss: 7.0457 - val_age_output_loss: 7.7189 - val_age_output_mae: 7.7180 - val_gender_output_accuracy: 0.8600 - val_gender_output_loss: 0.3238 - val_loss: 8.0405 - learning_rate: 2.5000e-05
# Epoch 53/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 6.7710 - age_output_mae: 6.7744 - gender_output_accuracy: 0.8561 - gender_output_loss: 0.3453 - loss: 7.1197 - val_age_output_loss: 7.6904 - val_age_output_mae: 7.6937 - val_gender_output_accuracy: 0.8560 - val_gender_output_loss: 0.3299 - val_loss: 8.0224 - learning_rate: 2.5000e-05
# Epoch 54/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - age_output_loss: 6.7198 - age_output_mae: 6.7227 - gender_output_accuracy: 0.8464 - gender_output_loss: 0.3541 - loss: 7.0766 - val_age_output_loss: 7.8599 - val_age_output_mae: 7.8578 - val_gender_output_accuracy: 0.8560 - val_gender_output_loss: 0.3255 - val_loss: 8.1818 - learning_rate: 2.5000e-05
# Epoch 55/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - age_output_loss: 6.8293 - age_output_mae: 6.8329 - gender_output_accuracy: 0.8576 - gender_output_loss: 0.3336 - loss: 7.1666 - val_age_output_loss: 7.7469 - val_age_output_mae: 7.7463 - val_gender_output_accuracy: 0.8570 - val_gender_output_loss: 0.3271 - val_loss: 8.0721 - learning_rate: 2.5000e-05
# Epoch 56/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - age_output_loss: 6.6494 - age_output_mae: 6.6516 - gender_output_accuracy: 0.8605 - gender_output_loss: 0.3424 - loss: 6.9942 - val_age_output_loss: 7.7993 - val_age_output_mae: 7.7949 - val_gender_output_accuracy: 0.8580 - val_gender_output_loss: 0.3289 - val_loss: 8.1223 - learning_rate: 2.5000e-05
# Epoch 57/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - age_output_loss: 6.7759 - age_output_mae: 6.7808 - gender_output_accuracy: 0.8629 - gender_output_loss: 0.3306 - loss: 7.1115 - val_age_output_loss: 7.6171 - val_age_output_mae: 7.6180 - val_gender_output_accuracy: 0.8580 - val_gender_output_loss: 0.3342 - val_loss: 7.9507 - learning_rate: 1.2500e-05
# Epoch 58/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 6.6973 - age_output_mae: 6.7001 - gender_output_accuracy: 0.8569 - gender_output_loss: 0.3525 - loss: 7.0527 - val_age_output_loss: 7.6734 - val_age_output_mae: 7.6748 - val_gender_output_accuracy: 0.8570 - val_gender_output_loss: 0.3316 - val_loss: 8.0051 - learning_rate: 1.2500e-05
# Epoch 59/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 6.6113 - age_output_mae: 6.6134 - gender_output_accuracy: 0.8501 - gender_output_loss: 0.3593 - loss: 6.9727 - val_age_output_loss: 7.6781 - val_age_output_mae: 7.6788 - val_gender_output_accuracy: 0.8560 - val_gender_output_loss: 0.3328 - val_loss: 8.0102 - learning_rate: 1.2500e-05
# Epoch 60/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 6.5471 - age_output_mae: 6.5504 - gender_output_accuracy: 0.8586 - gender_output_loss: 0.3403 - loss: 6.8908 - val_age_output_loss: 7.7462 - val_age_output_mae: 7.7454 - val_gender_output_accuracy: 0.8520 - val_gender_output_loss: 0.3299 - val_loss: 8.0740 - learning_rate: 1.2500e-05
# Epoch 61/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 6.6693 - age_output_mae: 6.6720 - gender_output_accuracy: 0.8583 - gender_output_loss: 0.3392 - loss: 7.0113 - val_age_output_loss: 7.7166 - val_age_output_mae: 7.7121 - val_gender_output_accuracy: 0.8520 - val_gender_output_loss: 0.3261 - val_loss: 8.0370 - learning_rate: 1.2500e-05
# Epoch 62/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - age_output_loss: 6.6475 - age_output_mae: 6.6517 - gender_output_accuracy: 0.8493 - gender_output_loss: 0.3309 - loss: 6.9826 - val_age_output_loss: 7.7096 - val_age_output_mae: 7.7080 - val_gender_output_accuracy: 0.8570 - val_gender_output_loss: 0.3251 - val_loss: 8.0319 - learning_rate: 1.2500e-05
# Epoch 63/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - age_output_loss: 6.5639 - age_output_mae: 6.5669 - gender_output_accuracy: 0.8527 - gender_output_loss: 0.3403 - loss: 6.9072 - val_age_output_loss: 7.6665 - val_age_output_mae: 7.6686 - val_gender_output_accuracy: 0.8530 - val_gender_output_loss: 0.3301 - val_loss: 7.9977 - learning_rate: 6.2500e-06
# Epoch 64/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 6.6273 - age_output_mae: 6.6319 - gender_output_accuracy: 0.8592 - gender_output_loss: 0.3333 - loss: 6.9654 - val_age_output_loss: 7.7067 - val_age_output_mae: 7.7113 - val_gender_output_accuracy: 0.8520 - val_gender_output_loss: 0.3339 - val_loss: 8.0440 - learning_rate: 6.2500e-06
# Epoch 65/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 6.6232 - age_output_mae: 6.6261 - gender_output_accuracy: 0.8594 - gender_output_loss: 0.3349 - loss: 6.9611 - val_age_output_loss: 7.6703 - val_age_output_mae: 7.6753 - val_gender_output_accuracy: 0.8560 - val_gender_output_loss: 0.3304 - val_loss: 8.0045 - learning_rate: 6.2500e-06
# Epoch 66/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - age_output_loss: 6.4976 - age_output_mae: 6.5009 - gender_output_accuracy: 0.8514 - gender_output_loss: 0.3294 - loss: 6.8302 - val_age_output_loss: 7.6806 - val_age_output_mae: 7.6851 - val_gender_output_accuracy: 0.8540 - val_gender_output_loss: 0.3319 - val_loss: 8.0157 - learning_rate: 6.2500e-06
# Epoch 67/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 6.5069 - age_output_mae: 6.5099 - gender_output_accuracy: 0.8604 - gender_output_loss: 0.3392 - loss: 6.8493 - val_age_output_loss: 7.6420 - val_age_output_mae: 7.6449 - val_gender_output_accuracy: 0.8530 - val_gender_output_loss: 0.3336 - val_loss: 7.9773 - learning_rate: 6.2500e-06
# Epoch 68/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 6.5236 - age_output_mae: 6.5265 - gender_output_accuracy: 0.8599 - gender_output_loss: 0.3226 - loss: 6.8492 - val_age_output_loss: 7.6520 - val_age_output_mae: 7.6566 - val_gender_output_accuracy: 0.8570 - val_gender_output_loss: 0.3317 - val_loss: 7.9870 - learning_rate: 3.1250e-06
# Epoch 69/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - age_output_loss: 6.4782 - age_output_mae: 6.4814 - gender_output_accuracy: 0.8630 - gender_output_loss: 0.3199 - loss: 6.8014 - val_age_output_loss: 7.6753 - val_age_output_mae: 7.6782 - val_gender_output_accuracy: 0.8520 - val_gender_output_loss: 0.3348 - val_loss: 8.0117 - learning_rate: 3.1250e-06
# Epoch 70/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - age_output_loss: 6.5704 - age_output_mae: 6.5739 - gender_output_accuracy: 0.8616 - gender_output_loss: 0.3142 - loss: 6.8882 - val_age_output_loss: 7.7196 - val_age_output_mae: 7.7237 - val_gender_output_accuracy: 0.8530 - val_gender_output_loss: 0.3345 - val_loss: 8.0568 - learning_rate: 3.1250e-06
# Epoch 71/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - age_output_loss: 6.4297 - age_output_mae: 6.4331 - gender_output_accuracy: 0.8675 - gender_output_loss: 0.3340 - loss: 6.7672 - val_age_output_loss: 7.7410 - val_age_output_mae: 7.7457 - val_gender_output_accuracy: 0.8520 - val_gender_output_loss: 0.3368 - val_loss: 8.0811 - learning_rate: 3.1250e-06
# Epoch 72/110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - age_output_loss: 6.4925 - age_output_mae: 6.4951 - gender_output_accuracy: 0.8624 - gender_output_loss: 0.3200 - loss: 6.8150 - val_age_output_loss: 7.6940 - val_age_output_mae: 7.6968 - val_gender_output_accuracy: 0.8500 - val_gender_output_loss: 0.3391 - val_loss: 8.0345 - learning_rate: 3.1250e-06
# Model training and saving completed.

# %% [markdown]
# ## STEP4A: Draw the learning curves
# Draw four learning curve figures for model A as follows.
# 1.	The loss of the gender classification over the training and validation set
# 2.	The accuracy of the gender classification over the training and validation set
# 3.	The loss of the age estimation over the training and validation set
# 4.	The MAE of the age estimation over the training and validation set

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 2, figsize=(15, 10))

axes[0, 0].plot(historyA.history['gender_output_loss'], label='Train Gender Loss')
axes[0, 0].plot(historyA.history['val_gender_output_loss'], label='Val Gender Loss')
axes[0, 0].set_title('Gender Classification Loss')
axes[0, 0].set_xlabel('Epoch')
axes[0, 0].set_ylabel('Loss (Binary Crossentropy)')
axes[0, 0].legend()
axes[0, 0].grid(True)

axes[0, 1].plot(historyA.history['gender_output_accuracy'], label='Train Gender Accuracy')
axes[0, 1].plot(historyA.history['val_gender_output_accuracy'], label='Val Gender Accuracy')
axes[0, 1].set_title('Gender Classification Accuracy')
axes[0, 1].set_xlabel('Epoch')
axes[0, 1].set_ylabel('Accuracy')
axes[0, 1].legend()
axes[0, 1].grid(True)
axes[0, 1].set_ylim([0.4, 1.0])  # Accuracy ranges from 0.4 to 1

axes[1, 0].plot(historyA.history['age_output_loss'], label='Train Age Loss (MAE)')
axes[1, 0].plot(historyA.history['val_age_output_loss'], label='Val Age Loss (MAE)')
axes[1, 0].set_title('Age Estimation Loss (MAE)')
axes[1, 0].set_xlabel('Epoch')
axes[1, 0].set_ylabel('MAE')
axes[1, 0].legend()
axes[1, 0].grid(True)

axes[1, 1].plot(historyA.history['age_output_mae'], label='Train Age MAE')
axes[1, 1].plot(historyA.history['val_age_output_mae'], label='Val Age MAE')
axes[1, 1].set_title('Age Estimation MAE')
axes[1, 1].set_xlabel('Epoch')
axes[1, 1].set_ylabel('MAE')
axes[1, 1].legend()
axes[1, 1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## STEP2B: Build a CNN network based on a pre-trained model
# Choose an existing CNN architecture pre-trained on ImageNet and fine-tune it on this dataset.
#
# As with Model A, **do not resize the input image size**.
# Ensure that the output layer for **the gender branch has only 1 unit**.
#
# At the end of the cell, use `modelB.summary()` to display the model architecture and use `plot_model()` to visualize the architecture.

# %%
import keras
from keras.layers import GlobalAveragePooling2D, Dense, BatchNormalization, Dropout
from keras.utils import plot_model

# %%
#import pre-trained model
base_model = keras.applications.InceptionResNetV2(
    weights="imagenet",
    input_shape=[128, 128, 3],
        include_top = False
)

#Freeze differnt layers model
for layer in base_model.layers[:-2]:
    layer.trainable = False


#write new top of the model:
inputs = keras.Input(shape=[128, 128, 3])
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)

#taking the same strucutre as model A
gender_output = Dense(1, activation='sigmoid', name='gender_output')(x)
age_output =  Dense(1,activation = 'relu', name='age_output')(x)

#create model
modelB = keras.Model(inputs, [gender_output, age_output])

modelB = keras.Model(inputs, [gender_output, age_output])

modelB.summary()
plot_model(modelB, show_shapes=True,dpi=100, to_file=os.path.join('/content/drive/MyDrive/', 'modelB_plot.png'))
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5             │ (None, 128, 128, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ inception_resnet_v2       │ (None, 2, 2, 1536)     │     54,336,736 │ input_layer_5[0][0]    │
# │ (Functional)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 1536)           │              0 │ inception_resnet_v2[0… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_611   │ (None, 1536)           │          6,144 │ global_average_poolin… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 1536)           │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gender_output (Dense)     │ (None, 1)              │          1,537 │ dropout_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ age_output (Dense)        │ (None, 1)              │          1,537 │ dropout_2[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 54,345,954 (207.31 MB)
#  Trainable params: 7,682 (30.01 KB)
#  Non-trainable params: 54,338,272 (207.28 MB)

# %% [markdown]
# ## STEP3B: Compile and train your model
# Compile and train your model here.
# Save your model to `age_gender_B.keras` after training.
#
# **DON'T use any other name for your model file.** This is because my test code relies on this particular model name. Any other file name will cause problem in the testing stage.
#
# **Also, save the model with `save()` instead of `save_weights()`.**

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_images, {'gender_output': train_gender, 'age_output': train_age}))

train_dataset = train_dataset.batch(128).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((val_images, {'gender_output': val_gender, 'age_output': val_age}))

val_dataset = val_dataset.batch(128).prefetch(tf.data.AUTOTUNE)


modelB.compile(optimizer=keras.optimizers.Adam(),
               loss={'gender_output': 'binary_crossentropy','age_output':'mean_absolute_error'},
               metrics = {'gender_output':['accuracy'], 'age_output': ['mae']}
)

#defining a variable learning rate
lr_schedule = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=5,
    min_delta = 0.01,
    restore_best_weights=True
)

epochs = 100
historyB = modelB.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=epochs,
    callbacks=[early_stopping, lr_schedule]
)

# Saving

your_model_folder = '/content/drive/MyDrive/'

modelB.save(your_model_folder+"age_gender_B.keras")

print("Model training and saving completed.")
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - age_output_loss: 31.6343 - age_output_mae: 31.6440 - gender_output_accuracy: 0.6118 - gender_output_loss: 0.7827 - loss: 32.4272 - val_age_output_loss: 32.6066 - val_age_output_mae: 32.6349 - val_gender_output_accuracy: 0.8040 - val_gender_output_loss: 0.4420 - val_loss: 33.0765 - learning_rate: 0.0010
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 220ms/step - age_output_loss: 24.8418 - age_output_mae: 24.8457 - gender_output_accuracy: 0.7825 - gender_output_loss: 0.5248 - loss: 25.3706 - val_age_output_loss: 30.5053 - val_age_output_mae: 30.5420 - val_gender_output_accuracy: 0.8120 - val_gender_output_loss: 0.4241 - val_loss: 30.9655 - learning_rate: 0.0010
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 217ms/step - age_output_loss: 21.0661 - age_output_mae: 21.0674 - gender_output_accuracy: 0.7869 - gender_output_loss: 0.4866 - loss: 21.5543 - val_age_output_loss: 27.3047 - val_age_output_mae: 27.3386 - val_gender_output_accuracy: 0.8190 - val_gender_output_loss: 0.4148 - val_loss: 27.7524 - learning_rate: 0.0010
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 221ms/step - age_output_loss: 19.3752 - age_output_mae: 19.3761 - gender_output_accuracy: 0.8028 - gender_output_loss: 0.4499 - loss: 19.8261 - val_age_output_loss: 23.7621 - val_age_output_mae: 23.7970 - val_gender_output_accuracy: 0.8100 - val_gender_output_loss: 0.4109 - val_loss: 24.2066 - learning_rate: 0.0010
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 219ms/step - age_output_loss: 17.8760 - age_output_mae: 17.8783 - gender_output_accuracy: 0.8082 - gender_output_loss: 0.4412 - loss: 18.3197 - val_age_output_loss: 20.1479 - val_age_output_mae: 20.1824 - val_gender_output_accuracy: 0.8240 - val_gender_output_loss: 0.3967 - val_loss: 20.5779 - learning_rate: 0.0010
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 226ms/step - age_output_loss: 16.3357 - age_output_mae: 16.3390 - gender_output_accuracy: 0.8016 - gender_output_loss: 0.4241 - loss: 16.7632 - val_age_output_loss: 17.0407 - val_age_output_mae: 17.0744 - val_gender_output_accuracy: 0.8240 - val_gender_output_loss: 0.3924 - val_loss: 17.4656 - learning_rate: 0.0010
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 261ms/step - age_output_loss: 14.8561 - age_output_mae: 14.8604 - gender_output_accuracy: 0.8199 - gender_output_loss: 0.4197 - loss: 15.2804 - val_age_output_loss: 14.7724 - val_age_output_mae: 14.8005 - val_gender_output_accuracy: 0.8280 - val_gender_output_loss: 0.3857 - val_loss: 15.1851 - learning_rate: 0.0010
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 218ms/step - age_output_loss: 13.5529 - age_output_mae: 13.5573 - gender_output_accuracy: 0.8136 - gender_output_loss: 0.4201 - loss: 13.9775 - val_age_output_loss: 12.9154 - val_age_output_mae: 12.9403 - val_gender_output_accuracy: 0.8260 - val_gender_output_loss: 0.3835 - val_loss: 13.3230 - learning_rate: 0.0010
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 223ms/step - age_output_loss: 12.2700 - age_output_mae: 12.2721 - gender_output_accuracy: 0.8176 - gender_output_loss: 0.4100 - loss: 12.6823 - val_age_output_loss: 11.5686 - val_age_output_mae: 11.5913 - val_gender_output_accuracy: 0.8250 - val_gender_output_loss: 0.3881 - val_loss: 11.9782 - learning_rate: 0.0010
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 229ms/step - age_output_loss: 11.2839 - age_output_mae: 11.2855 - gender_output_accuracy: 0.8242 - gender_output_loss: 0.4042 - loss: 11.6899 - val_age_output_loss: 10.6458 - val_age_output_mae: 10.6594 - val_gender_output_accuracy: 0.8260 - val_gender_output_loss: 0.3840 - val_loss: 11.0424 - learning_rate: 0.0010
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 227ms/step - age_output_loss: 10.5571 - age_output_mae: 10.5592 - gender_output_accuracy: 0.8369 - gender_output_loss: 0.3913 - loss: 10.9508 - val_age_output_loss: 10.1088 - val_age_output_mae: 10.1149 - val_gender_output_accuracy: 0.8220 - val_gender_output_loss: 0.3804 - val_loss: 10.4941 - learning_rate: 0.0010
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 221ms/step - age_output_loss: 10.1501 - age_output_mae: 10.1515 - gender_output_accuracy: 0.8290 - gender_output_loss: 0.3929 - loss: 10.5447 - val_age_output_loss: 9.8464 - val_age_output_mae: 9.8477 - val_gender_output_accuracy: 0.8270 - val_gender_output_loss: 0.3797 - val_loss: 10.2263 - learning_rate: 0.0010
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 223ms/step - age_output_loss: 9.9337 - age_output_mae: 9.9352 - gender_output_accuracy: 0.8316 - gender_output_loss: 0.3845 - loss: 10.3198 - val_age_output_loss: 9.6943 - val_age_output_mae: 9.6923 - val_gender_output_accuracy: 0.8200 - val_gender_output_loss: 0.3812 - val_loss: 10.0720 - learning_rate: 0.0010
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - age_output_loss: 9.9123 - age_output_mae: 9.9132 - gender_output_accuracy: 0.8317 - gender_output_loss: 0.3846 - loss: 10.2980 - val_age_output_loss: 9.5925 - val_age_output_mae: 9.5903 - val_gender_output_accuracy: 0.8260 - val_gender_output_loss: 0.3788 - val_loss: 9.9675 - learning_rate: 0.0010
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 222ms/step - age_output_loss: 9.7526 - age_output_mae: 9.7532 - gender_output_accuracy: 0.8382 - gender_output_loss: 0.3914 - loss: 10.1448 - val_age_output_loss: 9.5038 - val_age_output_mae: 9.5014 - val_gender_output_accuracy: 0.8280 - val_gender_output_loss: 0.3757 - val_loss: 9.8754 - learning_rate: 0.0010
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - age_output_loss: 9.5734 - age_output_mae: 9.5751 - gender_output_accuracy: 0.8428 - gender_output_loss: 0.3735 - loss: 9.9489 - val_age_output_loss: 9.4107 - val_age_output_mae: 9.4089 - val_gender_output_accuracy: 0.8140 - val_gender_output_loss: 0.3791 - val_loss: 9.7862 - learning_rate: 0.0010
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 233ms/step - age_output_loss: 9.5447 - age_output_mae: 9.5460 - gender_output_accuracy: 0.8475 - gender_output_loss: 0.3682 - loss: 9.9144 - val_age_output_loss: 9.3268 - val_age_output_mae: 9.3267 - val_gender_output_accuracy: 0.8150 - val_gender_output_loss: 0.3786 - val_loss: 9.7037 - learning_rate: 0.0010
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - age_output_loss: 9.4846 - age_output_mae: 9.4860 - gender_output_accuracy: 0.8464 - gender_output_loss: 0.3671 - loss: 9.8533 - val_age_output_loss: 9.3191 - val_age_output_mae: 9.3188 - val_gender_output_accuracy: 0.8140 - val_gender_output_loss: 0.3792 - val_loss: 9.6962 - learning_rate: 0.0010
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 229ms/step - age_output_loss: 9.3948 - age_output_mae: 9.3962 - gender_output_accuracy: 0.8443 - gender_output_loss: 0.3714 - loss: 9.7679 - val_age_output_loss: 9.2520 - val_age_output_mae: 9.2512 - val_gender_output_accuracy: 0.8170 - val_gender_output_loss: 0.3765 - val_loss: 9.6260 - learning_rate: 0.0010
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 225ms/step - age_output_loss: 9.3625 - age_output_mae: 9.3641 - gender_output_accuracy: 0.8402 - gender_output_loss: 0.3659 - loss: 9.7302 - val_age_output_loss: 9.2128 - val_age_output_mae: 9.2121 - val_gender_output_accuracy: 0.8140 - val_gender_output_loss: 0.3788 - val_loss: 9.5892 - learning_rate: 0.0010
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 224ms/step - age_output_loss: 9.4111 - age_output_mae: 9.4123 - gender_output_accuracy: 0.8372 - gender_output_loss: 0.3764 - loss: 9.7890 - val_age_output_loss: 9.1776 - val_age_output_mae: 9.1764 - val_gender_output_accuracy: 0.8200 - val_gender_output_loss: 0.3779 - val_loss: 9.5527 - learning_rate: 0.0010
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 229ms/step - age_output_loss: 9.2662 - age_output_mae: 9.2675 - gender_output_accuracy: 0.8499 - gender_output_loss: 0.3562 - loss: 9.6239 - val_age_output_loss: 9.1596 - val_age_output_mae: 9.1587 - val_gender_output_accuracy: 0.8250 - val_gender_output_loss: 0.3772 - val_loss: 9.5345 - learning_rate: 0.0010
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 234ms/step - age_output_loss: 9.2821 - age_output_mae: 9.2838 - gender_output_accuracy: 0.8356 - gender_output_loss: 0.3637 - loss: 9.6477 - val_age_output_loss: 9.0929 - val_age_output_mae: 9.0925 - val_gender_output_accuracy: 0.8240 - val_gender_output_loss: 0.3802 - val_loss: 9.4709 - learning_rate: 0.0010
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 224ms/step - age_output_loss: 9.2074 - age_output_mae: 9.2101 - gender_output_accuracy: 0.8450 - gender_output_loss: 0.3659 - loss: 9.5763 - val_age_output_loss: 9.0707 - val_age_output_mae: 9.0694 - val_gender_output_accuracy: 0.8310 - val_gender_output_loss: 0.3738 - val_loss: 9.4419 - learning_rate: 0.0010
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 222ms/step - age_output_loss: 9.2201 - age_output_mae: 9.2227 - gender_output_accuracy: 0.8530 - gender_output_loss: 0.3560 - loss: 9.5790 - val_age_output_loss: 9.1170 - val_age_output_mae: 9.1155 - val_gender_output_accuracy: 0.8200 - val_gender_output_loss: 0.3826 - val_loss: 9.4964 - learning_rate: 0.0010
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 211ms/step - age_output_loss: 9.1635 - age_output_mae: 9.1660 - gender_output_accuracy: 0.8396 - gender_output_loss: 0.3722 - loss: 9.5384 - val_age_output_loss: 9.0564 - val_age_output_mae: 9.0549 - val_gender_output_accuracy: 0.8300 - val_gender_output_loss: 0.3792 - val_loss: 9.4324 - learning_rate: 0.0010
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - age_output_loss: 9.0234 - age_output_mae: 9.0256 - gender_output_accuracy: 0.8471 - gender_output_loss: 0.3560 - loss: 9.3818 - val_age_output_loss: 9.0342 - val_age_output_mae: 9.0338 - val_gender_output_accuracy: 0.8240 - val_gender_output_loss: 0.3813 - val_loss: 9.4132 - learning_rate: 0.0010
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 225ms/step - age_output_loss: 9.1067 - age_output_mae: 9.1114 - gender_output_accuracy: 0.8490 - gender_output_loss: 0.3562 - loss: 9.4678 - val_age_output_loss: 9.0263 - val_age_output_mae: 9.0249 - val_gender_output_accuracy: 0.8300 - val_gender_output_loss: 0.3757 - val_loss: 9.3990 - learning_rate: 0.0010
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 228ms/step - age_output_loss: 9.0923 - age_output_mae: 9.0953 - gender_output_accuracy: 0.8459 - gender_output_loss: 0.3528 - loss: 9.4482 - val_age_output_loss: 8.9874 - val_age_output_mae: 8.9865 - val_gender_output_accuracy: 0.8290 - val_gender_output_loss: 0.3703 - val_loss: 9.3552 - learning_rate: 0.0010
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 215ms/step - age_output_loss: 9.0683 - age_output_mae: 9.0716 - gender_output_accuracy: 0.8468 - gender_output_loss: 0.3587 - loss: 9.4305 - val_age_output_loss: 8.9968 - val_age_output_mae: 8.9959 - val_gender_output_accuracy: 0.8300 - val_gender_output_loss: 0.3723 - val_loss: 9.3665 - learning_rate: 0.0010
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 222ms/step - age_output_loss: 8.9717 - age_output_mae: 8.9744 - gender_output_accuracy: 0.8477 - gender_output_loss: 0.3548 - loss: 9.3295 - val_age_output_loss: 8.9532 - val_age_output_mae: 8.9532 - val_gender_output_accuracy: 0.8320 - val_gender_output_loss: 0.3708 - val_loss: 9.3227 - learning_rate: 0.0010
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 215ms/step - age_output_loss: 8.9745 - age_output_mae: 8.9773 - gender_output_accuracy: 0.8511 - gender_output_loss: 0.3498 - loss: 9.3274 - val_age_output_loss: 8.9782 - val_age_output_mae: 8.9764 - val_gender_output_accuracy: 0.8340 - val_gender_output_loss: 0.3761 - val_loss: 9.3508 - learning_rate: 0.0010
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 215ms/step - age_output_loss: 9.0481 - age_output_mae: 9.0499 - gender_output_accuracy: 0.8515 - gender_output_loss: 0.3462 - loss: 9.3962 - val_age_output_loss: 8.9903 - val_age_output_mae: 8.9881 - val_gender_output_accuracy: 0.8250 - val_gender_output_loss: 0.3784 - val_loss: 9.3645 - learning_rate: 0.0010
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 225ms/step - age_output_loss: 9.0080 - age_output_mae: 9.0108 - gender_output_accuracy: 0.8473 - gender_output_loss: 0.3556 - loss: 9.3666 - val_age_output_loss: 8.9197 - val_age_output_mae: 8.9195 - val_gender_output_accuracy: 0.8320 - val_gender_output_loss: 0.3747 - val_loss: 9.2922 - learning_rate: 0.0010
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 232ms/step - age_output_loss: 8.9206 - age_output_mae: 8.9239 - gender_output_accuracy: 0.8523 - gender_output_loss: 0.3555 - loss: 9.2798 - val_age_output_loss: 8.9073 - val_age_output_mae: 8.9083 - val_gender_output_accuracy: 0.8390 - val_gender_output_loss: 0.3691 - val_loss: 9.2759 - learning_rate: 0.0010
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 217ms/step - age_output_loss: 8.9728 - age_output_mae: 8.9755 - gender_output_accuracy: 0.8542 - gender_output_loss: 0.3452 - loss: 9.3209 - val_age_output_loss: 8.9342 - val_age_output_mae: 8.9346 - val_gender_output_accuracy: 0.8280 - val_gender_output_loss: 0.3753 - val_loss: 9.3081 - learning_rate: 0.0010
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 221ms/step - age_output_loss: 8.8829 - age_output_mae: 8.8854 - gender_output_accuracy: 0.8452 - gender_output_loss: 0.3528 - loss: 9.2385 - val_age_output_loss: 8.8530 - val_age_output_mae: 8.8547 - val_gender_output_accuracy: 0.8340 - val_gender_output_loss: 0.3773 - val_loss: 9.2301 - learning_rate: 0.0010
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 213ms/step - age_output_loss: 8.7811 - age_output_mae: 8.7839 - gender_output_accuracy: 0.8451 - gender_output_loss: 0.3557 - loss: 9.1398 - val_age_output_loss: 8.8632 - val_age_output_mae: 8.8654 - val_gender_output_accuracy: 0.8320 - val_gender_output_loss: 0.3704 - val_loss: 9.2341 - learning_rate: 0.0010
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 252ms/step - age_output_loss: 8.7884 - age_output_mae: 8.7919 - gender_output_accuracy: 0.8450 - gender_output_loss: 0.3570 - loss: 9.1492 - val_age_output_loss: 8.9480 - val_age_output_mae: 8.9493 - val_gender_output_accuracy: 0.8380 - val_gender_output_loss: 0.3733 - val_loss: 9.3207 - learning_rate: 0.0010
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 210ms/step - age_output_loss: 8.8845 - age_output_mae: 8.8873 - gender_output_accuracy: 0.8443 - gender_output_loss: 0.3593 - loss: 9.2468 - val_age_output_loss: 8.8465 - val_age_output_mae: 8.8481 - val_gender_output_accuracy: 0.8240 - val_gender_output_loss: 0.3796 - val_loss: 9.2256 - learning_rate: 0.0010
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - age_output_loss: 8.7616 - age_output_mae: 8.7654 - gender_output_accuracy: 0.8475 - gender_output_loss: 0.3672 - loss: 9.1329 - val_age_output_loss: 8.8474 - val_age_output_mae: 8.8464 - val_gender_output_accuracy: 0.8360 - val_gender_output_loss: 0.3710 - val_loss: 9.2161 - learning_rate: 0.0010
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 209ms/step - age_output_loss: 8.8551 - age_output_mae: 8.8581 - gender_output_accuracy: 0.8427 - gender_output_loss: 0.3533 - loss: 9.2117 - val_age_output_loss: 8.8748 - val_age_output_mae: 8.8746 - val_gender_output_accuracy: 0.8280 - val_gender_output_loss: 0.3782 - val_loss: 9.2509 - learning_rate: 0.0010
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 219ms/step - age_output_loss: 8.7299 - age_output_mae: 8.7326 - gender_output_accuracy: 0.8468 - gender_output_loss: 0.3480 - loss: 9.0809 - val_age_output_loss: 8.8394 - val_age_output_mae: 8.8407 - val_gender_output_accuracy: 0.8350 - val_gender_output_loss: 0.3721 - val_loss: 9.2110 - learning_rate: 0.0010
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 222ms/step - age_output_loss: 8.7674 - age_output_mae: 8.7710 - gender_output_accuracy: 0.8509 - gender_output_loss: 0.3437 - loss: 9.1149 - val_age_output_loss: 8.8218 - val_age_output_mae: 8.8224 - val_gender_output_accuracy: 0.8340 - val_gender_output_loss: 0.3756 - val_loss: 9.1957 - learning_rate: 0.0010
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 218ms/step - age_output_loss: 8.8026 - age_output_mae: 8.8048 - gender_output_accuracy: 0.8481 - gender_output_loss: 0.3462 - loss: 9.1511 - val_age_output_loss: 8.8489 - val_age_output_mae: 8.8479 - val_gender_output_accuracy: 0.8360 - val_gender_output_loss: 0.3800 - val_loss: 9.2255 - learning_rate: 0.0010
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 217ms/step - age_output_loss: 8.8417 - age_output_mae: 8.8457 - gender_output_accuracy: 0.8579 - gender_output_loss: 0.3438 - loss: 9.1897 - val_age_output_loss: 8.8190 - val_age_output_mae: 8.8198 - val_gender_output_accuracy: 0.8330 - val_gender_output_loss: 0.3797 - val_loss: 9.1973 - learning_rate: 0.0010
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 210ms/step - age_output_loss: 8.7200 - age_output_mae: 8.7240 - gender_output_accuracy: 0.8492 - gender_output_loss: 0.3575 - loss: 9.0817 - val_age_output_loss: 8.8802 - val_age_output_mae: 8.8806 - val_gender_output_accuracy: 0.8350 - val_gender_output_loss: 0.3788 - val_loss: 9.2571 - learning_rate: 0.0010
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 216ms/step - age_output_loss: 8.7444 - age_output_mae: 8.7479 - gender_output_accuracy: 0.8516 - gender_output_loss: 0.3400 - loss: 9.0882 - val_age_output_loss: 8.8184 - val_age_output_mae: 8.8206 - val_gender_output_accuracy: 0.8340 - val_gender_output_loss: 0.3750 - val_loss: 9.1935 - learning_rate: 5.0000e-04
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 251ms/step - age_output_loss: 8.7294 - age_output_mae: 8.7326 - gender_output_accuracy: 0.8538 - gender_output_loss: 0.3432 - loss: 9.0759 - val_age_output_loss: 8.8846 - val_age_output_mae: 8.8866 - val_gender_output_accuracy: 0.8410 - val_gender_output_loss: 0.3754 - val_loss: 9.2599 - learning_rate: 5.0000e-04
# Model training and saving completed.

# %% [markdown]
# # plot

# %% [markdown]
# ## STEP4B: Draw the learning curves
# Draw four learning curve figures for model B as follows.
# 1. The loss of the gender classification over the training and validation set
# 2. The accuracy of the gender classification over the training and validation set
# 3. The loss of the age estimation over the training and validation set
# 4. The MAE of the age estimation over the training and validation set

# %%
import matplotlib.pyplot as plt

# Create a 2x2 subplot layout
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# Plot 1: Gender Classification Loss
axes[0, 0].plot(historyB.history['gender_output_loss'], label='Train Gender Loss')
axes[0, 0].plot(historyB.history['val_gender_output_loss'], label='Val Gender Loss')
axes[0, 0].set_title('Gender Classification Loss')
axes[0, 0].set_xlabel('Epoch')
axes[0, 0].set_ylabel('Loss (Binary Crossentropy)')
axes[0, 0].legend()
axes[0, 0].grid(True)

# Plot 2: Gender Classification Accuracy
axes[0, 1].plot(historyB.history['gender_output_accuracy'], label='Train Gender Accuracy')
axes[0, 1].plot(historyB.history['val_gender_output_accuracy'], label='Val Gender Accuracy')
axes[0, 1].set_title('Gender Classification Accuracy')
axes[0, 1].set_xlabel('Epoch')
axes[0, 1].set_ylabel('Accuracy')
axes[0, 1].legend()
axes[0, 1].grid(True)
axes[0, 1].set_ylim([0, 1.0])  # Accuracy ranges from 0 to 1

# Plot 3: Age Estimation Loss (MAE)
axes[1, 0].plot(historyB.history['age_output_loss'], label='Train Age Loss (MAE)')
axes[1, 0].plot(historyB.history['val_age_output_loss'], label='Val Age Loss (MAE)')
axes[1, 0].set_title('Age Estimation Loss (MAE)')
axes[1, 0].set_xlabel('Epoch')
axes[1, 0].set_ylabel('MAE')
axes[1, 0].legend()
axes[1, 0].grid(True)

# Plot 4: Age Estimation MAE
# If MAE is both the loss and a metric, 'mae' might be tracked separately; adjust if needed
axes[1, 1].plot(historyB.history['age_output_mae'], label='Train Age MAE')
axes[1, 1].plot(historyB.history['val_age_output_mae'], label='Val Age MAE')
axes[1, 1].set_title('Age Estimation MAE')
axes[1, 1].set_xlabel('Epoch')
axes[1, 1].set_ylabel('MAE')
axes[1, 1].legend()
axes[1, 1].grid(True)

# Adjust layout to prevent overlap
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/inception_variablelr_finetune2')
plt.show()

# %% [markdown]
# ## STEP5: Evaluate the model on the test set
# I will load your two models for testing. The test set will not be available before your submission.
#
# The metrics for measuring the performance on the test set are:
# - age estimation: MAE (Mean Absolute Error)
# - gender classification: accuracy

# %%
#
# Don't add code in this cell when submitting this file
#
